# %%
import os
import json
import numpy as np

# 현재 디렉토리 내 모든 JSON 파일 필터링
input_dir = "./"
input_files = [
    os.path.join(input_dir, f) for f in os.listdir(input_dir)
    if f.endswith(".json") and os.path.isfile(os.path.join(input_dir, f))
]

# 결과 저장
for file_path in input_files:
    try:
        with open(file_path, "r", encoding="utf-8") as f:
            data = json.load(f)
        
        var_scores_label_0 = [item["var_score"] for item in data if item.get("label") == 0 and "var_score" in item]
        var_scores_label_1 = [item["var_score"] for item in data if item.get("label") == 1 and "var_score" in item]
        var_scores_all = [item["var_score"] for item in data if "var_score" in item]

        avg_0 = np.mean(var_scores_label_0) if var_scores_label_0 else None
        avg_1 = np.mean(var_scores_label_1) if var_scores_label_1 else None
        avg_all = np.mean(var_scores_all) if var_scores_all else None

        print(f"📄 {os.path.basename(file_path)}")
        print(f"  ▶ label=0 평균 var_score: {avg_0}")
        print(f"  ▶ label=1 평균 var_score: {avg_1}")
        print(f"  ▶ 전체 평균 var_score: {avg_all}")
        print()

    except Exception as e:
        print(f"⚠️ 파일 처리 오류: {file_path} → {e}")
# Out:
# 📄 fizz_original_xsumfaith_e_min.json
#   ▶ label=0 평균 var_score: 0.06225821029217383
#   ▶ label=1 평균 var_score: 0.05218711764295149
#   ▶ 전체 평균 var_score: 0.06123498727901284
#
# 📄 fizz_original_frank_e-c_mean.json
#   ▶ label=0 평균 var_score: 0.11732147984667203
#   ▶ label=1 평균 var_score: 0.025648303362380432
#   ▶ 전체 평균 var_score: 0.08685483550092384
#
# 📄 fizz_original_xsumfaith_e-c_min.json
#   ▶ label=0 평균 var_score: 0.12257852405360056
#   ▶ label=1 평균 var_score: 0.08150942682583785
#   ▶ 전체 평균 var_score: 0.11840590377525986
#
# 📄 fizz_original_frank_e_mean.json
#   ▶ label=0 평균 var_score: 0.05685804429996666
#   ▶ label=1 평균 var_score: 0.014599536615264645
#   ▶ 전체 평균 var_score: 0.04281386067300907
#
# 📄 fizz_original_factcc_e_min.json
#   ▶ label=0 평균 var_score: 0.03674570167984871
#   ▶ label=1 평균 var_score: 0.005752452769549995
#   ▶ 전체 평균 var_score: 0.010146769478636386
#
# 📄 fizz_original_factcc_e-c_min.json
#   ▶ label=0 평균 var_score: 0.08148113981927804
#   ▶ label=1 평균 var_score: 0.009330928816630276
#   ▶ 전체 평균 var_score: 0.019560604275652302

# %%
import os
import json
import numpy as np
from collections import defaultdict

# 현재 디렉토리 내 모든 JSON 파일 필터링
input_dir = "./"
input_files = [
    os.path.join(input_dir, f) for f in os.listdir(input_dir)
    if f.endswith(".json") and os.path.isfile(os.path.join(input_dir, f))
]

# 결과 저장
for file_path in input_files:
    try:
        with open(file_path, "r", encoding="utf-8") as f:
            data = json.load(f)

        # length_of_summary에 따라 그룹핑
        grouped = defaultdict(lambda: {"label_0": [], "label_1": [], "all": []})

        for item in data:
            if "var_score" not in item or "length_of_summary" not in item:
                continue
            length = item["length_of_summary"]
            var_score = item["var_score"]
            label = item.get("label", None)

            grouped[length]["all"].append(var_score)
            if label == 0:
                grouped[length]["label_0"].append(var_score)
            elif label == 1:
                grouped[length]["label_1"].append(var_score)

        # 출력
        print(f"📄 {os.path.basename(file_path)}")
        for length, group in sorted(grouped.items()):
            avg_0 = np.mean(group["label_0"]) if group["label_0"] else None
            avg_1 = np.mean(group["label_1"]) if group["label_1"] else None
            avg_all = np.mean(group["all"]) if group["all"] else None

            print(f"  ▶ length_of_summary = {length}")
            print(f"    - label=0 평균 var_score: {avg_0}")
            print(f"    - label=1 평균 var_score: {avg_1}")
            print(f"    - 전체 평균 var_score: {avg_all}")
        print()

    except Exception as e:
        print(f"⚠️ 파일 처리 오류: {file_path} → {e}")
# Out:
# 📄 fizz_original_xsumfaith_e_min.json
#   ▶ length_of_summary = 1
#     - label=0 평균 var_score: 0.0
#     - label=1 평균 var_score: 0.0
#     - 전체 평균 var_score: 0.0
#   ▶ length_of_summary = 2
#     - label=0 평균 var_score: 0.045825338724132254
#     - label=1 평균 var_score: 0.035422385186078306
#     - 전체 평균 var_score: 0.044520308710397895
#   ▶ length_of_summary = 3
#     - label=0 평균 var_score: 0.06227295582412078
#     - label=1 평균 var_score: 0.056129085876222916
#     - 전체 평균 var_score: 0.06155993416672452
#   ▶ length_of_summary = 4
#     - label=0 평균 var_score: 0.0753788830961029
#     - label=1 평균 var_score: 0.061771430817575704
#     - 전체 평균 var_score: 0.07439088326069829
#   ▶ length_of_summary = 5
#     - label=0 평균 var_score: 0.0781822486053144
#     - label=1 평균 var_score: 0.08265797857275706
#     - 전체 평균 var_score: 0.07852987811734878
#   ▶ length_of_summary = 6
#     - label=0 평균 var_score: 0.09110048906118684
#     - label=1 평균 var_score: None
#     - 전체 평균 var_score: 0.09110048906118684
#   ▶ length_of_summary = 7
#     - label=0 평균 var_score: 0.11493285485316818
#     - label=1 평균 var_score: None
#     - 전체 평균 var_score: 0.11493285485316818
#   ▶ length_of_summary = 8
#     - label=0 평균 var_score: 0.07069388466581725
#     - label=1 평균 var_score: None
#     - 전체 평균 var_score: 0.07069388466581725
#
# 📄 fizz_original_frank_e-c_mean.json
#   ▶ length_of_summary = 1
#     - label=0 평균 var_score: 0.0
#     - label=1 평균 var_score: None
#     - 전체 평균 var_score: 0.0
#   ▶ length_of_summary = 2
#     - label=0 평균 var_score: 0.10607522889819843
#     - label=1 평균 var_score: 0.09220102706422134
#     - 전체 평균 var_score: 0.10512494110135068
#   ▶ length_of_summary = 3
#     - label=0 평균 var_score: 0.129506055101954
#     - label=1 평균 var_score: 0.11379118020840624
#     - 전체 평균 var_score: 0.1284442392307684
#   ▶ length_of_summary = 4
#     - label=0 평균 var_score: 0.18497938737979733
#     - label=1 평균 var_score: 0.048812172086019685
#     - 전체 평균 var_score: 0.17664261909650483
#   ▶ length_of_summary = 5
#     - label=0 평균 var_score: 0.13277764116945714
#     - label=1 평균 var_score: 0.036405641522536676
#     - 전체 평균 var_score: 0.10443293539095115
#   ▶ length_of_summary = 6
#     - label=0 평균 var_score: 0.1494694673481969
#     - label=1 평균 var_score: 0.013851510372421091
#     - 전체 평균 var_score: 0.08687656412860806
#   ▶ length_of_summary = 7
#     - label=0 평균 var_score: 0.12385068584602256
#     - label=1 평균 var_score: 0.01675873485080533
#     - 전체 평균 var_score: 0.06702638531794812
#   ▶ length_of_summary = 8
#     - label=0 평균 var_score: 0.07853113830713908
#     - label=1 평균 var_score: 0.024967021980701852
#     - 전체 평균 var_score: 0.0490708743275986
#   ▶ length_of_summary = 9
#     - label=0 평균 var_score: 0.07431741964520101
#     - label=1 평균 var_score: 0.01879496587447905
#     - 전체 평균 var_score: 0.0408124906456274
#   ▶ length_of_summary = 10
#     - label=0 평균 var_score: 0.08578067224602762
#     - label=1 평균 var_score: 0.03577490410389882
#     - 전체 평균 var_score: 0.05772865597117487
#   ▶ length_of_summary = 11
#     - label=0 평균 var_score: 0.10424213599840684
#     - label=1 평균 var_score: 0.010834555536680068
#     - 전체 평균 var_score: 0.058735878850386114
#   ▶ length_of_summary = 12
#     - label=0 평균 var_score: 0.06601213262362184
#     - label=1 평균 var_score: 0.0031208383954351533
#     - 전체 평균 var_score: 0.02827735608670982
#   ▶ length_of_summary = 13
#     - label=0 평균 var_score: 0.08308730321462059
#     - label=1 평균 var_score: 0.019872501900989967
#     - 전체 평균 var_score: 0.05599524550877889
#   ▶ length_of_summary = 14
#     - label=0 평균 var_score: 0.04696518959063539
#     - label=1 평균 var_score: 0.022680031823668626
#     - 전체 평균 var_score: 0.034822610707152014
#   ▶ length_of_summary = 15
#     - label=0 평균 var_score: None
#     - label=1 평균 var_score: 0.011039624969435571
#     - 전체 평균 var_score: 0.011039624969435571
#   ▶ length_of_summary = 16
#     - label=0 평균 var_score: 0.0012962883247414339
#     - label=1 평균 var_score: 0.0018665132756195137
#     - 전체 평균 var_score: 0.0016764382919934873
#   ▶ length_of_summary = 17
#     - label=0 평균 var_score: None
#     - label=1 평균 var_score: 0.0021568685725986427
#     - 전체 평균 var_score: 0.0021568685725986427
#   ▶ length_of_summary = 18
#     - label=0 평균 var_score: 0.046253457403128515
#     - label=1 평균 var_score: 0.001959003138903671
#     - 전체 평균 var_score: 0.024106230271016094
#   ▶ length_of_summary = 22
#     - label=0 평균 var_score: 0.02340804190743939
#     - label=1 평균 var_score: None
#     - 전체 평균 var_score: 0.02340804190743939
#
# 📄 fizz_original_xsumfaith_e-c_min.json
#   ▶ length_of_summary = 1
#     - label=0 평균 var_score: 0.0
#     - label=1 평균 var_score: 0.0
#     - 전체 평균 var_score: 0.0
#   ▶ length_of_summary = 2
#     - label=0 평균 var_score: 0.08994575628157876
#     - label=1 평균 var_score: 0.05292602657256019
#     - 전체 평균 var_score: 0.08530170416754417
#   ▶ length_of_summary = 3
#     - label=0 평균 var_score: 0.12324374935411524
#     - label=1 평균 var_score: 0.08567119403667514
#     - 전체 평균 var_score: 0.11888329806002161
#   ▶ length_of_summary = 4
#     - label=0 평균 var_score: 0.1429232725023637
#     - label=1 평균 var_score: 0.10139869749237124
#     - 전체 평균 var_score: 0.13990828685807383
#   ▶ length_of_summary = 5
#     - label=0 평균 var_score: 0.16663642725688077
#     - label=1 평균 var_score: 0.14103041122614102
#     - 전체 평균 var_score: 0.16464761047779417
#   ▶ length_of_summary = 6
#     - label=0 평균 var_score: 0.18981263692781247
#     - label=1 평균 var_score: None
#     - 전체 평균 var_score: 0.18981263692781247
#   ▶ length_of_summary = 7
#     - label=0 평균 var_score: 0.2197021861740457
#     - label=1 평균 var_score: None
#     - 전체 평균 var_score: 0.2197021861740457
#   ▶ length_of_summary = 8
#     - label=0 평균 var_score: 0.10803043582441879
#     - label=1 평균 var_score: None
#     - 전체 평균 var_score: 0.10803043582441879
#
# 📄 fizz_original_frank_e_mean.json
#   ▶ length_of_summary = 1
#     - label=0 평균 var_score: 0.0
#     - label=1 평균 var_score: None
#     - 전체 평균 var_score: 0.0
#   ▶ length_of_summary = 2
#     - label=0 평균 var_score: 0.051001876904795115
#     - label=1 평균 var_score: 0.05278128202183582
#     - 전체 평균 var_score: 0.05112375396760612
#   ▶ length_of_summary = 3
#     - label=0 평균 var_score: 0.06164836567122701
#     - label=1 평균 var_score: 0.04413094167531736
#     - 전체 평균 var_score: 0.06046475594177365
#   ▶ length_of_summary = 4
#     - label=0 평균 var_score: 0.08323649491497694
#     - label=1 평균 var_score: 0.03515057571298186
#     - 전체 평균 var_score: 0.08029245904546704
#   ▶ length_of_summary = 5
#     - label=0 평균 var_score: 0.06791821790259378
#     - label=1 평균 var_score: 0.011670013701922315
#     - 전체 평균 var_score: 0.051374628431808046
#   ▶ length_of_summary = 6
#     - label=0 평균 var_score: 0.08080984213419366
#     - label=1 평균 var_score: 0.007564622977884174
#     - 전체 평균 var_score: 0.047004356369743136
#   ▶ length_of_summary = 7
#     - label=0 평균 var_score: 0.05867157242845407
#     - label=1 평균 var_score: 0.012127443280900034
#     - 전체 평균 var_score: 0.03397468757464989
#   ▶ length_of_summary = 8
#     - label=0 평균 var_score: 0.04902214754060834
#     - label=1 평균 var_score: 0.015789709389011714
#     - 전체 평균 var_score: 0.03074430655723019
#   ▶ length_of_summary = 9
#     - label=0 평균 var_score: 0.03437719819855023
#     - label=1 평균 var_score: 0.013808497200867093
#     - 전체 평균 var_score: 0.021965051044775925
#   ▶ length_of_summary = 10
#     - label=0 평균 var_score: 0.048253025872655786
#     - label=1 평균 var_score: 0.02052791632030161
#     - 전체 평균 var_score: 0.032699915635969294
#   ▶ length_of_summary = 11
#     - label=0 평균 var_score: 0.04698970715454585
#     - label=1 평균 var_score: 0.006741425879441636
#     - 전체 평균 var_score: 0.027381570123084824
#   ▶ length_of_summary = 12
#     - label=0 평균 var_score: 0.024578872933255013
#     - label=1 평균 var_score: 0.0019393997789384923
#     - 전체 평균 var_score: 0.010995189040665104
#   ▶ length_of_summary = 13
#     - label=0 평균 var_score: 0.04285706741845832
#     - label=1 평균 var_score: 0.012497632353217566
#     - 전체 평균 var_score: 0.029845880961926564
#   ▶ length_of_summary = 14
#     - label=0 평균 var_score: 0.02247709528992403
#     - label=1 평균 var_score: 0.019309465591316802
#     - 전체 평균 var_score: 0.02089328044062042
#   ▶ length_of_summary = 15
#     - label=0 평균 var_score: None
#     - label=1 평균 var_score: 0.00583846945393355
#     - 전체 평균 var_score: 0.00583846945393355
#   ▶ length_of_summary = 16
#     - label=0 평균 var_score: 0.0012113448763723667
#     - label=1 평균 var_score: 0.0016626727359049104
#     - 전체 평균 var_score: 0.0015122301160607292
#   ▶ length_of_summary = 17
#     - label=0 평균 var_score: None
#     - label=1 평균 var_score: 0.001188071411983913
#     - 전체 평균 var_score: 0.001188071411983913
#   ▶ length_of_summary = 18
#     - label=0 평균 var_score: 0.012950010355378972
#     - label=1 평균 var_score: 0.001588780601133504
#     - 전체 평균 var_score: 0.007269395478256238
#   ▶ length_of_summary = 22
#     - label=0 평균 var_score: 0.006558561848251279
#     - label=1 평균 var_score: None
#     - 전체 평균 var_score: 0.006558561848251279
#
# 📄 fizz_original_factcc_e_min.json
#   ▶ length_of_summary = 1
#     - label=0 평균 var_score: 0.0
#     - label=1 평균 var_score: 0.0
#     - 전체 평균 var_score: 0.0
#   ▶ length_of_summary = 2
#     - label=0 평균 var_score: 0.04451918025438265
#     - label=1 평균 var_score: 0.005662046370922652
#     - 전체 평균 var_score: 0.012100583089984338
#   ▶ length_of_summary = 3
#     - label=0 평균 var_score: 0.03685561891501903
#     - label=1 평균 var_score: 0.005337311575341092
#     - 전체 평균 var_score: 0.009277099992800837
#   ▶ length_of_summary = 4
#     - label=0 평균 var_score: 0.05418223359287267
#     - label=1 평균 var_score: 0.010250741491124609
#     - 전체 평균 var_score: 0.014419423223407273
#   ▶ length_of_summary = 5
#     - label=0 평균 var_score: 0.03722648896318347
#     - label=1 평균 var_score: 0.0034988586556262396
#     - 전체 평균 var_score: 0.004462505235842161
#   ▶ length_of_summary = 6
#     - label=0 평균 var_score: None
#     - label=1 평균 var_score: 0.001654568003328335
#     - 전체 평균 var_score: 0.001654568003328335
#   ▶ length_of_summary = 7
#     - label=0 평균 var_score: 0.02330782713889102
#     - label=1 평균 var_score: 0.00039773605132188667
#     - 전체 평균 var_score: 0.011852781595106453
#
# 📄 fizz_original_factcc_e-c_min.json
#   ▶ length_of_summary = 1
#     - label=0 평균 var_score: 0.0
#     - label=1 평균 var_score: 0.0
#     - 전체 평균 var_score: 0.0
#   ▶ length_of_summary = 2
#     - label=0 평균 var_score: 0.10091807311743367
#     - label=1 평균 var_score: 0.009773282416012054
#     - 전체 평균 var_score: 0.024875762270608077
#   ▶ length_of_summary = 3
#     - label=0 평균 var_score: 0.07934409223455625
#     - label=1 평균 var_score: 0.007589336478401501
#     - 전체 평균 var_score: 0.01655868094792085
#   ▶ length_of_summary = 4
#     - label=0 평균 var_score: 0.12229009822575879
#     - label=1 평균 var_score: 0.018309407715095455
#     - 전체 평균 var_score: 0.02817618856647227
#   ▶ length_of_summary = 5
#     - label=0 평균 var_score: 0.05190682697523086
#     - label=1 평균 var_score: 0.0039753257097546145
#     - 전체 평균 var_score: 0.0053447971744825075
#   ▶ length_of_summary = 6
#     - label=0 평균 var_score: None
#     - label=1 평균 var_score: 0.0018755809257214268
#     - 전체 평균 var_score: 0.0018755809257214268
#   ▶ length_of_summary = 7
#     - label=0 평균 var_score: 0.029050310689523764
#     - label=1 평균 var_score: 0.0005584491585455106
#     - 전체 평균 var_score: 0.014804379924034636

# %%
import os
import json
import numpy as np
from collections import defaultdict

# 현재 디렉토리 내 모든 JSON 파일 필터링
input_dir = "./"
input_files = [
    os.path.join(input_dir, f) for f in os.listdir(input_dir)
    if f.endswith(".json") and os.path.isfile(os.path.join(input_dir, f))
]

# 결과 저장
for file_path in input_files:
    try:
        with open(file_path, "r", encoding="utf-8") as f:
            data = json.load(f)

        # length_of_summary에 따라 그룹핑
        grouped = defaultdict(lambda: {
            "label_0": [],
            "label_1": [],
            "all": [],
            "count_0": 0,
            "count_1": 0
        })

        for item in data:
            if "var_score" not in item or "length_of_summary" not in item:
                continue
            length = item["length_of_summary"]
            var_score = item["var_score"]
            label = item.get("label", None)

            grouped[length]["all"].append(var_score)
            if label == 0:
                grouped[length]["label_0"].append(var_score)
                grouped[length]["count_0"] += 1
            elif label == 1:
                grouped[length]["label_1"].append(var_score)
                grouped[length]["count_1"] += 1

        # 출력
        print(f"📄 {os.path.basename(file_path)}")
        for length, group in sorted(grouped.items()):
            total_count = group["count_0"] + group["count_1"]
            avg_0 = np.mean(group["label_0"]) if group["label_0"] else None
            avg_1 = np.mean(group["label_1"]) if group["label_1"] else None
            avg_all = np.mean(group["all"]) if group["all"] else None

            print(f"  ▶ length_of_summary = {length} (총 {total_count}개)")
            print(f"    - label=0: {group['count_0']}개, 평균 var_score: {avg_0}")
            print(f"    - label=1: {group['count_1']}개, 평균 var_score: {avg_1}")
            print(f"    - 전체 평균 var_score: {avg_all}")
        print()

    except Exception as e:
        print(f"⚠️ 파일 처리 오류: {file_path} → {e}")
# Out:
# 📄 fizz_original_xsumfaith_e_min.json
#   ▶ length_of_summary = 1 (총 30개)
#     - label=0: 28개, 평균 var_score: 0.0
#     - label=1: 2개, 평균 var_score: 0.0
#     - 전체 평균 var_score: 0.0
#   ▶ length_of_summary = 2 (총 279개)
#     - label=0: 244개, 평균 var_score: 0.045825338724132254
#     - label=1: 35개, 평균 var_score: 0.035422385186078306
#     - 전체 평균 var_score: 0.044520308710397895
#   ▶ length_of_summary = 3 (총 517개)
#     - label=0: 457개, 평균 var_score: 0.06227295582412078
#     - label=1: 60개, 평균 var_score: 0.056129085876222916
#     - 전체 평균 var_score: 0.06155993416672452
#   ▶ length_of_summary = 4 (총 303개)
#     - label=0: 281개, 평균 var_score: 0.0753788830961029
#     - label=1: 22개, 평균 var_score: 0.061771430817575704
#     - 전체 평균 var_score: 0.07439088326069829
#   ▶ length_of_summary = 5 (총 103개)
#     - label=0: 95개, 평균 var_score: 0.0781822486053144
#     - label=1: 8개, 평균 var_score: 0.08265797857275706
#     - 전체 평균 var_score: 0.07852987811734878
#   ▶ length_of_summary = 6 (총 15개)
#     - label=0: 15개, 평균 var_score: 0.09110048906118684
#     - label=1: 0개, 평균 var_score: None
#     - 전체 평균 var_score: 0.09110048906118684
#   ▶ length_of_summary = 7 (총 2개)
#     - label=0: 2개, 평균 var_score: 0.11493285485316818
#     - label=1: 0개, 평균 var_score: None
#     - 전체 평균 var_score: 0.11493285485316818
#   ▶ length_of_summary = 8 (총 1개)
#     - label=0: 1개, 평균 var_score: 0.07069388466581725
#     - label=1: 0개, 평균 var_score: None
#     - 전체 평균 var_score: 0.07069388466581725
#
# 📄 fizz_original_frank_e-c_mean.json
#   ▶ length_of_summary = 1 (총 6개)
#     - label=0: 6개, 평균 var_score: 0.0
#     - label=1: 0개, 평균 var_score: None
#     - 전체 평균 var_score: 0.0
#   ▶ length_of_summary = 2 (총 73개)
#     - label=0: 68개, 평균 var_score: 0.10607522889819843
#     - label=1: 5개, 평균 var_score: 0.09220102706422134
#     - 전체 평균 var_score: 0.10512494110135068
#   ▶ length_of_summary = 3 (총 148개)
#     - label=0: 138개, 평균 var_score: 0.129506055101954
#     - label=1: 10개, 평균 var_score: 0.11379118020840624
#     - 전체 평균 var_score: 0.1284442392307684
#   ▶ length_of_summary = 4 (총 49개)
#     - label=0: 46개, 평균 var_score: 0.18497938737979733
#     - label=1: 3개, 평균 var_score: 0.048812172086019685
#     - 전체 평균 var_score: 0.17664261909650483
#   ▶ length_of_summary = 5 (총 34개)
#     - label=0: 24개, 평균 var_score: 0.13277764116945714
#     - label=1: 10개, 평균 var_score: 0.036405641522536676
#     - 전체 평균 var_score: 0.10443293539095115
#   ▶ length_of_summary = 6 (총 39개)
#     - label=0: 21개, 평균 var_score: 0.1494694673481969
#     - label=1: 18개, 평균 var_score: 0.013851510372421091
#     - 전체 평균 var_score: 0.08687656412860806
#   ▶ length_of_summary = 7 (총 49개)
#     - label=0: 23개, 평균 var_score: 0.12385068584602256
#     - label=1: 26개, 평균 var_score: 0.01675873485080533
#     - 전체 평균 var_score: 0.06702638531794812
#   ▶ length_of_summary = 8 (총 60개)
#     - label=0: 27개, 평균 var_score: 0.07853113830713908
#     - label=1: 33개, 평균 var_score: 0.024967021980701852
#     - 전체 평균 var_score: 0.0490708743275986
#   ▶ length_of_summary = 9 (총 58개)
#     - label=0: 23개, 평균 var_score: 0.07431741964520101
#     - label=1: 35개, 평균 var_score: 0.01879496587447905
#     - 전체 평균 var_score: 0.0408124906456274
#   ▶ length_of_summary = 10 (총 41개)
#     - label=0: 18개, 평균 var_score: 0.08578067224602762
#     - label=1: 23개, 평균 var_score: 0.03577490410389882
#     - 전체 평균 var_score: 0.05772865597117487
#   ▶ length_of_summary = 11 (총 39개)
#     - label=0: 20개, 평균 var_score: 0.10424213599840684
#     - label=1: 19개, 평균 var_score: 0.010834555536680068
#     - 전체 평균 var_score: 0.058735878850386114
#   ▶ length_of_summary = 12 (총 30개)
#     - label=0: 12개, 평균 var_score: 0.06601213262362184
#     - label=1: 18개, 평균 var_score: 0.0031208383954351533
#     - 전체 평균 var_score: 0.02827735608670982
#   ▶ length_of_summary = 13 (총 28개)
#     - label=0: 16개, 평균 var_score: 0.08308730321462059
#     - label=1: 12개, 평균 var_score: 0.019872501900989967
#     - 전체 평균 var_score: 0.05599524550877889
#   ▶ length_of_summary = 14 (총 6개)
#     - label=0: 3개, 평균 var_score: 0.04696518959063539
#     - label=1: 3개, 평균 var_score: 0.022680031823668626
#     - 전체 평균 var_score: 0.034822610707152014
#   ▶ length_of_summary = 15 (총 4개)
#     - label=0: 0개, 평균 var_score: None
#     - label=1: 4개, 평균 var_score: 0.011039624969435571
#     - 전체 평균 var_score: 0.011039624969435571
#   ▶ length_of_summary = 16 (총 3개)
#     - label=0: 1개, 평균 var_score: 0.0012962883247414339
#     - label=1: 2개, 평균 var_score: 0.0018665132756195137
#     - 전체 평균 var_score: 0.0016764382919934873
#   ▶ length_of_summary = 17 (총 1개)
#     - label=0: 0개, 평균 var_score: None
#     - label=1: 1개, 평균 var_score: 0.0021568685725986427
#     - 전체 평균 var_score: 0.0021568685725986427
#   ▶ length_of_summary = 18 (총 2개)
#     - label=0: 1개, 평균 var_score: 0.046253457403128515
#     - label=1: 1개, 평균 var_score: 0.001959003138903671
#     - 전체 평균 var_score: 0.024106230271016094
#   ▶ length_of_summary = 22 (총 1개)
#     - label=0: 1개, 평균 var_score: 0.02340804190743939
#     - label=1: 0개, 평균 var_score: None
#     - 전체 평균 var_score: 0.02340804190743939
#
# 📄 fizz_original_xsumfaith_e-c_min.json
#   ▶ length_of_summary = 1 (총 30개)
#     - label=0: 28개, 평균 var_score: 0.0
#     - label=1: 2개, 평균 var_score: 0.0
#     - 전체 평균 var_score: 0.0
#   ▶ length_of_summary = 2 (총 279개)
#     - label=0: 244개, 평균 var_score: 0.08994575628157876
#     - label=1: 35개, 평균 var_score: 0.05292602657256019
#     - 전체 평균 var_score: 0.08530170416754417
#   ▶ length_of_summary = 3 (총 517개)
#     - label=0: 457개, 평균 var_score: 0.12324374935411524
#     - label=1: 60개, 평균 var_score: 0.08567119403667514
#     - 전체 평균 var_score: 0.11888329806002161
#   ▶ length_of_summary = 4 (총 303개)
#     - label=0: 281개, 평균 var_score: 0.1429232725023637
#     - label=1: 22개, 평균 var_score: 0.10139869749237124
#     - 전체 평균 var_score: 0.13990828685807383
#   ▶ length_of_summary = 5 (총 103개)
#     - label=0: 95개, 평균 var_score: 0.16663642725688077
#     - label=1: 8개, 평균 var_score: 0.14103041122614102
#     - 전체 평균 var_score: 0.16464761047779417
#   ▶ length_of_summary = 6 (총 15개)
#     - label=0: 15개, 평균 var_score: 0.18981263692781247
#     - label=1: 0개, 평균 var_score: None
#     - 전체 평균 var_score: 0.18981263692781247
#   ▶ length_of_summary = 7 (총 2개)
#     - label=0: 2개, 평균 var_score: 0.2197021861740457
#     - label=1: 0개, 평균 var_score: None
#     - 전체 평균 var_score: 0.2197021861740457
#   ▶ length_of_summary = 8 (총 1개)
#     - label=0: 1개, 평균 var_score: 0.10803043582441879
#     - label=1: 0개, 평균 var_score: None
#     - 전체 평균 var_score: 0.10803043582441879
#
# 📄 fizz_original_frank_e_mean.json
#   ▶ length_of_summary = 1 (총 6개)
#     - label=0: 6개, 평균 var_score: 0.0
#     - label=1: 0개, 평균 var_score: None
#     - 전체 평균 var_score: 0.0
#   ▶ length_of_summary = 2 (총 73개)
#     - label=0: 68개, 평균 var_score: 0.051001876904795115
#     - label=1: 5개, 평균 var_score: 0.05278128202183582
#     - 전체 평균 var_score: 0.05112375396760612
#   ▶ length_of_summary = 3 (총 148개)
#     - label=0: 138개, 평균 var_score: 0.06164836567122701
#     - label=1: 10개, 평균 var_score: 0.04413094167531736
#     - 전체 평균 var_score: 0.06046475594177365
#   ▶ length_of_summary = 4 (총 49개)
#     - label=0: 46개, 평균 var_score: 0.08323649491497694
#     - label=1: 3개, 평균 var_score: 0.03515057571298186
#     - 전체 평균 var_score: 0.08029245904546704
#   ▶ length_of_summary = 5 (총 34개)
#     - label=0: 24개, 평균 var_score: 0.06791821790259378
#     - label=1: 10개, 평균 var_score: 0.011670013701922315
#     - 전체 평균 var_score: 0.051374628431808046
#   ▶ length_of_summary = 6 (총 39개)
#     - label=0: 21개, 평균 var_score: 0.08080984213419366
#     - label=1: 18개, 평균 var_score: 0.007564622977884174
#     - 전체 평균 var_score: 0.047004356369743136
#   ▶ length_of_summary = 7 (총 49개)
#     - label=0: 23개, 평균 var_score: 0.05867157242845407
#     - label=1: 26개, 평균 var_score: 0.012127443280900034
#     - 전체 평균 var_score: 0.03397468757464989
#   ▶ length_of_summary = 8 (총 60개)
#     - label=0: 27개, 평균 var_score: 0.04902214754060834
#     - label=1: 33개, 평균 var_score: 0.015789709389011714
#     - 전체 평균 var_score: 0.03074430655723019
#   ▶ length_of_summary = 9 (총 58개)
#     - label=0: 23개, 평균 var_score: 0.03437719819855023
#     - label=1: 35개, 평균 var_score: 0.013808497200867093
#     - 전체 평균 var_score: 0.021965051044775925
#   ▶ length_of_summary = 10 (총 41개)
#     - label=0: 18개, 평균 var_score: 0.048253025872655786
#     - label=1: 23개, 평균 var_score: 0.02052791632030161
#     - 전체 평균 var_score: 0.032699915635969294
#   ▶ length_of_summary = 11 (총 39개)
#     - label=0: 20개, 평균 var_score: 0.04698970715454585
#     - label=1: 19개, 평균 var_score: 0.006741425879441636
#     - 전체 평균 var_score: 0.027381570123084824
#   ▶ length_of_summary = 12 (총 30개)
#     - label=0: 12개, 평균 var_score: 0.024578872933255013
#     - label=1: 18개, 평균 var_score: 0.0019393997789384923
#     - 전체 평균 var_score: 0.010995189040665104
#   ▶ length_of_summary = 13 (총 28개)
#     - label=0: 16개, 평균 var_score: 0.04285706741845832
#     - label=1: 12개, 평균 var_score: 0.012497632353217566
#     - 전체 평균 var_score: 0.029845880961926564
#   ▶ length_of_summary = 14 (총 6개)
#     - label=0: 3개, 평균 var_score: 0.02247709528992403
#     - label=1: 3개, 평균 var_score: 0.019309465591316802
#     - 전체 평균 var_score: 0.02089328044062042
#   ▶ length_of_summary = 15 (총 4개)
#     - label=0: 0개, 평균 var_score: None
#     - label=1: 4개, 평균 var_score: 0.00583846945393355
#     - 전체 평균 var_score: 0.00583846945393355
#   ▶ length_of_summary = 16 (총 3개)
#     - label=0: 1개, 평균 var_score: 0.0012113448763723667
#     - label=1: 2개, 평균 var_score: 0.0016626727359049104
#     - 전체 평균 var_score: 0.0015122301160607292
#   ▶ length_of_summary = 17 (총 1개)
#     - label=0: 0개, 평균 var_score: None
#     - label=1: 1개, 평균 var_score: 0.001188071411983913
#     - 전체 평균 var_score: 0.001188071411983913
#   ▶ length_of_summary = 18 (총 2개)
#     - label=0: 1개, 평균 var_score: 0.012950010355378972
#     - label=1: 1개, 평균 var_score: 0.001588780601133504
#     - 전체 평균 var_score: 0.007269395478256238
#   ▶ length_of_summary = 22 (총 1개)
#     - label=0: 1개, 평균 var_score: 0.006558561848251279
#     - label=1: 0개, 평균 var_score: None
#     - 전체 평균 var_score: 0.006558561848251279
#
# 📄 fizz_original_factcc_e_min.json
#   ▶ length_of_summary = 1 (총 70개)
#     - label=0: 18개, 평균 var_score: 0.0
#     - label=1: 52개, 평균 var_score: 0.0
#     - 전체 평균 var_score: 0.0
#   ▶ length_of_summary = 2 (총 344개)
#     - label=0: 57개, 평균 var_score: 0.04451918025438265
#     - label=1: 287개, 평균 var_score: 0.005662046370922652
#     - 전체 평균 var_score: 0.012100583089984338
#   ▶ length_of_summary = 3 (총 336개)
#     - label=0: 42개, 평균 var_score: 0.03685561891501903
#     - label=1: 294개, 평균 var_score: 0.005337311575341092
#     - 전체 평균 var_score: 0.009277099992800837
#   ▶ length_of_summary = 4 (총 137개)
#     - label=0: 13개, 평균 var_score: 0.05418223359287267
#     - label=1: 124개, 평균 var_score: 0.010250741491124609
#     - 전체 평균 var_score: 0.014419423223407273
#   ▶ length_of_summary = 5 (총 35개)
#     - label=0: 1개, 평균 var_score: 0.03722648896318347
#     - label=1: 34개, 평균 var_score: 0.0034988586556262396
#     - 전체 평균 var_score: 0.004462505235842161
#   ▶ length_of_summary = 6 (총 7개)
#     - label=0: 0개, 평균 var_score: None
#     - label=1: 7개, 평균 var_score: 0.001654568003328335
#     - 전체 평균 var_score: 0.001654568003328335
#   ▶ length_of_summary = 7 (총 2개)
#     - label=0: 1개, 평균 var_score: 0.02330782713889102
#     - label=1: 1개, 평균 var_score: 0.00039773605132188667
#     - 전체 평균 var_score: 0.011852781595106453
#
# 📄 fizz_original_factcc_e-c_min.json
#   ▶ length_of_summary = 1 (총 70개)
#     - label=0: 18개, 평균 var_score: 0.0
#     - label=1: 52개, 평균 var_score: 0.0
#     - 전체 평균 var_score: 0.0
#   ▶ length_of_summary = 2 (총 344개)
#     - label=0: 57개, 평균 var_score: 0.10091807311743367
#     - label=1: 287개, 평균 var_score: 0.009773282416012054
#     - 전체 평균 var_score: 0.024875762270608077
#   ▶ length_of_summary = 3 (총 336개)
#     - label=0: 42개, 평균 var_score: 0.07934409223455625
#     - label=1: 294개, 평균 var_score: 0.007589336478401501
#     - 전체 평균 var_score: 0.01655868094792085
#   ▶ length_of_summary = 4 (총 137개)
#     - label=0: 13개, 평균 var_score: 0.12229009822575879
#     - label=1: 124개, 평균 var_score: 0.018309407715095455
#     - 전체 평균 var_score: 0.02817618856647227
#   ▶ length_of_summary = 5 (총 35개)
#     - label=0: 1개, 평균 var_score: 0.05190682697523086
#     - label=1: 34개, 평균 var_score: 0.0039753257097546145
#     - 전체 평균 var_score: 0.0053447971744825075
#   ▶ length_of_summary = 6 (총 7개)
#     - label=0: 0개, 평균 var_score: None
#     - label=1: 7개, 평균 var_score: 0.0018755809257214268
#     - 전체 평균 var_score: 0.0018755809257214268
#   ▶ length_of_summary = 7 (총 2개)
#     - label=0: 1개, 평균 var_score: 0.029050310689523764
#     - label=1: 1개, 평균 var_score: 0.0005584491585455106
#     - 전체 평균 var_score: 0.014804379924034636

# %%
import os
import json
import numpy as np
from collections import defaultdict

# 현재 디렉토리 내 모든 JSON 파일 필터링
input_dir = "./"
input_files = [
    os.path.join(input_dir, f) for f in os.listdir(input_dir)
    if f.endswith(".json") and os.path.isfile(os.path.join(input_dir, f))
]

# 결과 저장
for file_path in input_files:
    try:
        with open(file_path, "r", encoding="utf-8") as f:
            data = json.load(f)

        # length_of_summary에 따라 그룹핑
        grouped = defaultdict(lambda: {
            "label_0_var": [],
            "label_1_var": [],
            "label_0_mean": [],
            "label_1_mean": [],
            "all_var": [],
            "all_mean": [],
            "count_0": 0,
            "count_1": 0
        })

        for item in data:
            if "var_score" not in item or "length_of_summary" not in item or "mean_score" not in item:
                continue
            length = item["length_of_summary"]
            var_score = item["var_score"]
            mean_score = item["mean_score"]
            label = item.get("label", None)

            grouped[length]["all_var"].append(var_score)
            grouped[length]["all_mean"].append(mean_score)
            if label == 0:
                grouped[length]["label_0_var"].append(var_score)
                grouped[length]["label_0_mean"].append(mean_score)
                grouped[length]["count_0"] += 1
            elif label == 1:
                grouped[length]["label_1_var"].append(var_score)
                grouped[length]["label_1_mean"].append(mean_score)
                grouped[length]["count_1"] += 1

        # 출력
        print(f"📄 {os.path.basename(file_path)}")
        for length, group in sorted(grouped.items()):
            total_count = group["count_0"] + group["count_1"]

            # var_score 평균
            avg_var_0 = np.mean(group["label_0_var"]) if group["label_0_var"] else None
            avg_var_1 = np.mean(group["label_1_var"]) if group["label_1_var"] else None
            avg_var_all = np.mean(group["all_var"]) if group["all_var"] else None

            # mean_score 평균
            avg_mean_0 = np.mean(group["label_0_mean"]) if group["label_0_mean"] else None
            avg_mean_1 = np.mean(group["label_1_mean"]) if group["label_1_mean"] else None
            avg_mean_all = np.mean(group["all_mean"]) if group["all_mean"] else None

            print(f"  ▶ length_of_summary = {length} (총 {total_count}개)")
            print(f"    - label=0: {group['count_0']}개")
            print(f"        · 평균 var_score: {avg_var_0}")
            print(f"        · 평균 mean_score: {avg_mean_0}")
            print(f"    - label=1: {group['count_1']}개")
            print(f"        · 평균 var_score: {avg_var_1}")
            print(f"        · 평균 mean_score: {avg_mean_1}")
            print(f"    - 전체 평균 var_score: {avg_var_all}")
            print(f"    - 전체 평균 mean_score: {avg_mean_all}")
        print()

    except Exception as e:
        print(f"⚠️ 파일 처리 오류: {file_path} → {e}")
# Out:
# 📄 fizz_original_factcc_e-c_min.json
#   ▶ length_of_summary = 1 (총 70개)
#     - label=0: 18개
#         · 평균 var_score: 0.0
#         · 평균 mean_score: 0.2631594410114404
#     - label=1: 52개
#         · 평균 var_score: 0.0
#         · 평균 mean_score: 0.9369321889602221
#     - 전체 평균 var_score: 0.0
#     - 전체 평균 mean_score: 0.7636763394876782
#   ▶ length_of_summary = 2 (총 346개)
#     - label=0: 57개
#         · 평균 var_score: 0.10148429826699011
#         · 평균 mean_score: 0.4803799584598828
#     - label=1: 289개
#         · 평균 var_score: 0.009712075532176503
#         · 평균 mean_score: 0.9312817836568045
#     - 전체 평균 var_score: 0.024830620896004168
#     - 전체 평균 mean_score: 0.8570002691012423
#   ▶ length_of_summary = 3 (총 336개)
#     - label=0: 42개
#         · 평균 var_score: 0.07934407841346378
#         · 평균 mean_score: 0.5295425392174538
#     - label=1: 294개
#         · 평균 var_score: 0.00803740880105808
#         · 평균 mean_score: 0.9367903402956732
#     - 전체 평균 var_score: 0.016950742502608793
#     - 전체 평균 mean_score: 0.8858843651608959
#   ▶ length_of_summary = 4 (총 136개)
#     - label=0: 13개
#         · 평균 var_score: 0.12229014730545978
#         · 평균 mean_score: 0.6399900841755041
#     - label=1: 123개
#         · 평균 var_score: 0.018385231453357076
#         · 평균 mean_score: 0.9297846783708773
#     - 전체 평균 var_score: 0.028317318998043364
#     - 전체 평균 mean_score: 0.9020837245139667
#   ▶ length_of_summary = 5 (총 34개)
#     - label=0: 1개
#         · 평균 var_score: 0.05190683806801506
#         · 평균 mean_score: 0.7346865222789347
#     - label=1: 33개
#         · 평균 var_score: 0.004097276869348599
#         · 평균 mean_score: 0.9318109090358838
#     - 전체 평균 var_score: 0.0055034404340152596
#     - 전체 평균 mean_score: 0.926013132954797
#   ▶ length_of_summary = 6 (총 7개)
#     - label=0: 0개
#         · 평균 var_score: None
#         · 평균 mean_score: None
#     - label=1: 7개
#         · 평균 var_score: 0.0018755799652989025
#         · 평균 mean_score: 0.9517359366831702
#     - 전체 평균 var_score: 0.0018755799652989025
#     - 전체 평균 mean_score: 0.9517359366831702
#   ▶ length_of_summary = 7 (총 2개)
#     - label=0: 1개
#         · 평균 var_score: 0.022590489147538306
#         · 평균 mean_score: 0.8785463685219709
#     - label=1: 1개
#         · 평균 var_score: 0.0005584502999634527
#         · 평균 mean_score: 0.9550502573672149
#     - 전체 평균 var_score: 0.011574469723750879
#     - 전체 평균 mean_score: 0.9167983129445929
#
# 📄 fizz_original_factcc_e_min.json
#   ▶ length_of_summary = 1 (총 70개)
#     - label=0: 18개
#         · 평균 var_score: 0.0
#         · 평균 mean_score: 0.5011879221225778
#     - label=1: 52개
#         · 평균 var_score: 0.0
#         · 평균 mean_score: 0.9575582292790596
#     - 전체 평균 var_score: 0.0
#     - 전체 평균 mean_score: 0.8402058645816786
#   ▶ length_of_summary = 2 (총 346개)
#     - label=0: 57개
#         · 평균 var_score: 0.044897306962924766
#         · 평균 mean_score: 0.6232720120940685
#     - label=1: 289개
#         · 평균 var_score: 0.005628216815822146
#         · 평균 mean_score: 0.9439813557586868
#     - 전체 평균 var_score: 0.012097402186876622
#     - 전체 평균 mean_score: 0.8911477355596022
#   ▶ length_of_summary = 3 (총 336개)
#     - label=0: 42개
#         · 평균 var_score: 0.03685561622471426
#         · 평균 mean_score: 0.6570334320976621
#     - label=1: 294개
#         · 평균 var_score: 0.005418930014766775
#         · 평균 mean_score: 0.9464017894328096
#     - 전체 평균 var_score: 0.00934851579101021
#     - 전체 평균 mean_score: 0.9102307447659163
#   ▶ length_of_summary = 4 (총 136개)
#     - label=0: 13개
#         · 평균 var_score: 0.05418223919974762
#         · 평균 mean_score: 0.7421738083402698
#     - label=1: 123개
#         · 평균 var_score: 0.01027815094348908
#         · 평균 mean_score: 0.9421855920539578
#     - 전체 평균 var_score: 0.01447486526210203
#     - 전체 평균 mean_score: 0.9230668186107377
#   ▶ length_of_summary = 5 (총 34개)
#     - label=0: 1개
#         · 평균 var_score: 0.037226499214310135
#         · 평균 mean_score: 0.7902069389820099
#     - label=1: 33개
#         · 평균 var_score: 0.0036068707359541803
#         · 평균 mean_score: 0.9423201557361718
#     - 전체 평균 var_score: 0.004595683338258768
#     - 전체 평균 mean_score: 0.9378462375963437
#   ▶ length_of_summary = 6 (총 7개)
#     - label=0: 0개
#         · 평균 var_score: None
#         · 평균 mean_score: None
#     - label=1: 7개
#         · 평균 var_score: 0.0016545674654749613
#         · 평균 mean_score: 0.9562447567780812
#     - 전체 평균 var_score: 0.0016545674654749613
#     - 전체 평균 mean_score: 0.9562447567780812
#   ▶ length_of_summary = 7 (총 2개)
#     - label=0: 1개
#         · 평균 var_score: 0.016951232294257542
#         · 평균 mean_score: 0.8938965371676854
#     - label=1: 1개
#         · 평균 var_score: 0.0003977366922381047
#         · 평균 mean_score: 0.9626730169568744
#     - 전체 평균 var_score: 0.008674484493247824
#     - 전체 평균 mean_score: 0.9282847770622799
#
# 📄 fizz_original_frank_e_min.json
#   ▶ length_of_summary = 1 (총 6개)
#     - label=0: 6개
#         · 평균 var_score: 0.0
#         · 평균 mean_score: 0.16512848204001784
#     - label=1: 0개
#         · 평균 var_score: None
#         · 평균 mean_score: None
#     - 전체 평균 var_score: 0.0
#     - 전체 평균 mean_score: 0.16512848204001784
#   ▶ length_of_summary = 2 (총 72개)
#     - label=0: 67개
#         · 평균 var_score: 0.05206701986034242
#         · 평균 mean_score: 0.40344345351462185
#     - label=1: 5개
#         · 평균 var_score: 0.05278126620005282
#         · 평균 mean_score: 0.6872340366244316
#     - 전체 평균 var_score: 0.05211662030060009
#     - 전체 평균 mean_score: 0.4231511328972475
#   ▶ length_of_summary = 3 (총 148개)
#     - label=0: 138개
#         · 평균 var_score: 0.0615508772590295
#         · 평균 mean_score: 0.3785543604495211
#     - label=1: 10개
#         · 평균 var_score: 0.04425622007909521
#         · 평균 mean_score: 0.5974161441127459
#     - 전체 평균 var_score: 0.06038231934146638
#     - 전체 평균 mean_score: 0.39334231880514436
#   ▶ length_of_summary = 4 (총 50개)
#     - label=0: 47개
#         · 평균 var_score: 0.08220737122949727
#         · 평균 mean_score: 0.3832754346116649
#     - label=1: 3개
#         · 평균 var_score: 0.03515060974389457
#         · 평균 mean_score: 0.6260168988568088
#     - 전체 평균 var_score: 0.0793839655403611
#     - 전체 평균 mean_score: 0.39783992246637356
#   ▶ length_of_summary = 5 (총 34개)
#     - label=0: 24개
#         · 평균 var_score: 0.06791824001512055
#         · 평균 mean_score: 0.4812322536172966
#     - label=1: 10개
#         · 평균 var_score: 0.01166998269212808
#         · 평균 mean_score: 0.8279852258786559
#     - 전체 평균 var_score: 0.05137463492012278
#     - 전체 평균 mean_score: 0.5832184219294612
#   ▶ length_of_summary = 6 (총 39개)
#     - label=0: 21개
#         · 평균 var_score: 0.08080982778804507
#         · 평균 mean_score: 0.6933724426531365
#     - label=1: 18개
#         · 평균 var_score: 0.007564672512564934
#         · 평균 mean_score: 0.961340755638149
#     - 전체 평균 var_score: 0.04700437150705425
#     - 전체 평균 mean_score: 0.8170501255692962
#   ▶ length_of_summary = 7 (총 47개)
#     - label=0: 22개
#         · 평균 var_score: 0.060606738836166255
#         · 평균 mean_score: 0.7820816244688128
#     - label=1: 25개
#         · 평균 var_score: 0.006837186054476893
#         · 평균 mean_score: 0.946221720661436
#     - 전체 평균 var_score: 0.03200591288845915
#     - 전체 평균 mean_score: 0.8693901862733995
#   ▶ length_of_summary = 8 (총 62개)
#     - label=0: 28개
#         · 평균 var_score: 0.04835528231333243
#         · 평균 mean_score: 0.8362822656469818
#     - label=1: 34개
#         · 평균 var_score: 0.02017861847615167
#         · 평균 mean_score: 0.9203094978583977
#     - 전체 평균 var_score: 0.032903563434878456
#     - 전체 평균 mean_score: 0.8823617155693712
#   ▶ length_of_summary = 9 (총 57개)
#     - label=0: 23개
#         · 평균 var_score: 0.034377176897333384
#         · 평균 mean_score: 0.8532452949858158
#     - label=1: 34개
#         · 평균 var_score: 0.014184157148765747
#         · 평균 mean_score: 0.9339789752939753
#     - 전체 평균 var_score: 0.022332217749064968
#     - 전체 평균 mean_score: 0.9014022270994548
#   ▶ length_of_summary = 10 (총 42개)
#     - label=0: 18개
#         · 평균 var_score: 0.048253028207200156
#         · 평균 mean_score: 0.8417852969271027
#     - label=1: 24개
#         · 평균 var_score: 0.019676860304006283
#         · 평균 mean_score: 0.9141176641297837
#     - 전체 평균 var_score: 0.03192378940537509
#     - 전체 평균 mean_score: 0.8831180781857778
#   ▶ length_of_summary = 11 (총 38개)
#     - label=0: 20개
#         · 평균 var_score: 0.04698970598322262
#         · 평균 mean_score: 0.818644902019084
#     - label=1: 18개
#         · 평균 var_score: 0.007067595688724333
#         · 평균 mean_score: 0.9612610909071836
#     - 전체 평균 var_score: 0.028079232685828688
#     - 전체 평균 mean_score: 0.8861999388608154
#   ▶ length_of_summary = 12 (총 32개)
#     - label=0: 12개
#         · 평균 var_score: 0.02457887408703316
#         · 평균 mean_score: 0.8714767442240068
#     - label=1: 20개
#         · 평균 var_score: 0.00200240744950931
#         · 평균 mean_score: 0.9615246847271918
#     - 전체 평균 var_score: 0.010468582438580752
#     - 전체 평균 mean_score: 0.9277567070384976
#   ▶ length_of_summary = 13 (총 25개)
#     - label=0: 15개
#         · 평균 var_score: 0.04564689200360669
#         · 평균 mean_score: 0.8407591352764613
#     - label=1: 10개
#         · 평균 var_score: 0.014481554488645881
#         · 평균 mean_score: 0.9395082351106863
#     - 전체 평균 var_score: 0.03318075699762236
#     - 전체 평균 mean_score: 0.8802587752101512
#   ▶ length_of_summary = 14 (총 6개)
#     - label=0: 3개
#         · 평균 var_score: 0.02247711845223693
#         · 평균 mean_score: 0.9023468148495469
#     - label=1: 3개
#         · 평균 var_score: 0.014403503051771287
#         · 평균 mean_score: 0.9289473650001344
#     - 전체 평균 var_score: 0.01844031075200411
#     - 전체 평균 mean_score: 0.9156470899248407
#   ▶ length_of_summary = 15 (총 7개)
#     - label=0: 1개
#         · 평균 var_score: 0.0036432973443360894
#         · 평균 mean_score: 0.9582181413968404
#     - label=1: 6개
#         · 평균 var_score: 0.0071063253228053624
#         · 평균 mean_score: 0.9470524426963594
#     - 전체 평균 var_score: 0.006611607040166895
#     - 전체 평균 mean_score: 0.9486475425107138
#   ▶ length_of_summary = 16 (총 2개)
#     - label=0: 1개
#         · 평균 var_score: 0.0012113421688039056
#         · 평균 mean_score: 0.9743934459984303
#     - label=1: 1개
#         · 평균 var_score: 7.241346674224935e-05
#         · 평균 mean_score: 0.9831656366586685
#     - 전체 평균 var_score: 0.0006418778177730775
#     - 전체 평균 mean_score: 0.9787795413285494
#   ▶ length_of_summary = 17 (총 1개)
#     - label=0: 0개
#         · 평균 var_score: None
#         · 평균 mean_score: None
#     - label=1: 1개
#         · 평균 var_score: 0.0011880720371229034
#         · 평균 mean_score: 0.9559974740533268
#     - 전체 평균 var_score: 0.0011880720371229034
#     - 전체 평균 mean_score: 0.9559974740533268
#   ▶ length_of_summary = 18 (총 2개)
#     - label=0: 1개
#         · 평균 var_score: 0.012949996972211343
#         · 평균 mean_score: 0.951105910870764
#     - label=1: 1개
#         · 평균 var_score: 0.001588781606931791
#         · 평균 mean_score: 0.9567407170931498
#     - 전체 평균 var_score: 0.007269389289571567
#     - 전체 평균 mean_score: 0.953923313981957
#   ▶ length_of_summary = 22 (총 1개)
#     - label=0: 1개
#         · 평균 var_score: 0.006558548178319279
#         · 평균 mean_score: 0.9577146741476926
#     - label=1: 0개
#         · 평균 var_score: None
#         · 평균 mean_score: None
#     - 전체 평균 var_score: 0.006558548178319279
#     - 전체 평균 mean_score: 0.9577146741476926
#
# 📄 fizz_original_xsumfaith_e-c_min.json
#   ▶ length_of_summary = 1 (총 30개)
#     - label=0: 28개
#         · 평균 var_score: 0.0
#         · 평균 mean_score: -0.06921705956171666
#     - label=1: 2개
#         · 평균 var_score: 0.0
#         · 평균 mean_score: 0.6793531712610275
#     - 전체 평균 var_score: 0.0
#     - 전체 평균 mean_score: -0.01931237750686705
#   ▶ length_of_summary = 2 (총 282개)
#     - label=0: 246개
#         · 평균 var_score: 0.08917734162510772
#         · 평균 mean_score: 0.16127740093734025
#     - label=1: 36개
#         · 평균 var_score: 0.05159225561002771
#         · 평균 mean_score: 0.49663283573560574
#     - 전체 평균 var_score: 0.08437924553807623
#     - 전체 평균 mean_score: 0.2040887330392465
#   ▶ length_of_summary = 3 (총 514개)
#     - label=0: 455개
#         · 평균 var_score: 0.12283281555781761
#         · 평균 mean_score: 0.15136836396919173
#     - label=1: 59개
#         · 평균 var_score: 0.08661597295129085
#         · 평균 mean_score: 0.5252552665309654
#     - 전체 평균 var_score: 0.11867562934422797
#     - 전체 평균 mean_score: 0.1942853430570218
#   ▶ length_of_summary = 4 (총 302개)
#     - label=0: 280개
#         · 평균 var_score: 0.14230853849566577
#         · 평균 mean_score: 0.18096561690986812
#     - label=1: 22개
#         · 평균 var_score: 0.10139875852323943
#         · 평균 mean_score: 0.546002152106005
#     - 전체 평균 var_score: 0.13932835584866785
#     - 전체 평균 mean_score: 0.20755768238773242
#   ▶ length_of_summary = 5 (총 103개)
#     - label=0: 95개
#         · 평균 var_score: 0.16663643392781052
#         · 평균 mean_score: 0.1145766281977443
#     - label=1: 8개
#         · 평균 var_score: 0.14103033973961338
#         · 평균 mean_score: 0.4228169388952665
#     - 전체 평균 var_score: 0.16464761107824186
#     - 전체 평균 mean_score: 0.1385176232033771
#   ▶ length_of_summary = 6 (총 16개)
#     - label=0: 16개
#         · 평균 var_score: 0.19439162936592658
#         · 평균 mean_score: 0.175272951968509
#     - label=1: 0개
#         · 평균 var_score: None
#         · 평균 mean_score: None
#     - 전체 평균 var_score: 0.19439162936592658
#     - 전체 평균 mean_score: 0.175272951968509
#   ▶ length_of_summary = 7 (총 2개)
#     - label=0: 2개
#         · 평균 var_score: 0.21970224886765818
#         · 평균 mean_score: 0.06513015300567661
#     - label=1: 0개
#         · 평균 var_score: None
#         · 평균 mean_score: None
#     - 전체 평균 var_score: 0.21970224886765818
#     - 전체 평균 mean_score: 0.06513015300567661
#   ▶ length_of_summary = 8 (총 1개)
#     - label=0: 1개
#         · 평균 var_score: 0.10803048446966129
#         · 평균 mean_score: 0.01769655878888443
#     - label=1: 0개
#         · 평균 var_score: None
#         · 평균 mean_score: None
#     - 전체 평균 var_score: 0.10803048446966129
#     - 전체 평균 mean_score: 0.01769655878888443
#
# 📄 fizz_original_frank_e-c_min.json
#   ▶ length_of_summary = 1 (총 6개)
#     - label=0: 6개
#         · 평균 var_score: 0.0
#         · 평균 mean_score: -0.16339907624448338
#     - label=1: 0개
#         · 평균 var_score: None
#         · 평균 mean_score: None
#     - 전체 평균 var_score: 0.0
#     - 전체 평균 mean_score: -0.16339907624448338
#   ▶ length_of_summary = 2 (총 72개)
#     - label=0: 67개
#         · 평균 var_score: 0.10773598329952783
#         · 평균 mean_score: 0.22865261284220936
#     - label=1: 5개
#         · 평균 var_score: 0.0922009961361139
#         · 평균 mean_score: 0.6270483407191932
#     - 전체 평균 var_score: 0.10665716474651298
#     - 전체 평균 mean_score: 0.25631898283366655
#   ▶ length_of_summary = 3 (총 148개)
#     - label=0: 138개
#         · 평균 var_score: 0.1298689564466144
#         · 평균 mean_score: 0.19471771341854263
#     - label=1: 10개
#         · 평균 var_score: 0.1138986692354127
#         · 평균 mean_score: 0.4637433535108964
#     - 전체 평균 var_score: 0.12878988298639804
#     - 전체 평균 mean_score: 0.21289512153289086
#   ▶ length_of_summary = 4 (총 50개)
#     - label=0: 47개
#         · 평균 var_score: 0.18253046611846183
#         · 평균 mean_score: 0.19280223137398123
#     - label=1: 3개
#         · 평균 var_score: 0.04881221016816514
#         · 평균 mean_score: 0.5752935578736166
#     - 전체 평균 var_score: 0.17450737076144404
#     - 전체 평균 mean_score: 0.21575171096395934
#   ▶ length_of_summary = 5 (총 34개)
#     - label=0: 24개
#         · 평균 var_score: 0.13277767840584007
#         · 평균 mean_score: 0.3352418765973804
#     - label=1: 10개
#         · 평균 var_score: 0.03640553920343641
#         · 평균 mean_score: 0.7738129880616907
#     - 전체 평균 var_score: 0.1044329315816037
#     - 전체 평균 mean_score: 0.46423337996923636
#   ▶ length_of_summary = 6 (총 39개)
#     - label=0: 21개
#         · 평균 var_score: 0.1494693357976766
#         · 평균 mean_score: 0.6061352718476436
#     - label=1: 18개
#         · 평균 var_score: 0.013851556498290625
#         · 평균 mean_score: 0.9525470233407017
#     - 전체 평균 var_score: 0.08687651458257539
#     - 전체 평균 mean_score: 0.7660176186905934
#   ▶ length_of_summary = 7 (총 47개)
#     - label=0: 22개
#         · 평균 var_score: 0.12744282452991607
#         · 평균 mean_score: 0.6924367024126318
#     - label=1: 25개
#         · 평균 var_score: 0.010777339017566494
#         · 평균 mean_score: 0.9353871842761459
#     - 전체 평균 var_score: 0.06538671521483651
#     - 전체 평균 mean_score: 0.8216656821272668
#   ▶ length_of_summary = 8 (총 62개)
#     - label=0: 28개
#         · 평균 var_score: 0.07796102068180906
#         · 평균 mean_score: 0.7970700504062863
#     - label=1: 34개
#         · 평균 var_score: 0.03387199663135455
#         · 평균 mean_score: 0.8995066216989739
#     - 전체 평균 var_score: 0.05378316878317271
#     - 전체 평균 mean_score: 0.853244944340986
#   ▶ length_of_summary = 9 (총 57개)
#     - label=0: 23개
#         · 평균 var_score: 0.07431737259729211
#         · 평균 mean_score: 0.7994277675942334
#     - label=1: 34개
#         · 평균 var_score: 0.019316763617228002
#         · 평균 mean_score: 0.9235585476735946
#     - 전체 평균 var_score: 0.04150999180216616
#     - 전체 평균 mean_score: 0.8734706890450805
#   ▶ length_of_summary = 10 (총 42개)
#     - label=0: 18개
#         · 평균 var_score: 0.0857806803139603
#         · 평균 mean_score: 0.7963011353399554
#     - label=1: 24개
#         · 평균 var_score: 0.03428953368098455
#         · 평균 mean_score: 0.8911913657221401
#     - 전체 평균 var_score: 0.05635716795225987
#     - 전체 평균 mean_score: 0.8505241241297751
#   ▶ length_of_summary = 11 (총 38개)
#     - label=0: 20개
#         · 평균 var_score: 0.10424212558994402
#         · 평균 mean_score: 0.7442097725870552
#     - label=1: 18개
#         · 평균 var_score: 0.011364251144903798
#         · 평균 mean_score: 0.9532749962352387
#     - 전체 평균 var_score: 0.06024734295808288
#     - 전체 평균 mean_score: 0.8432406679993526
#   ▶ length_of_summary = 12 (총 32개)
#     - label=0: 12개
#         · 평균 var_score: 0.06601218731447317
#         · 평균 mean_score: 0.8170897076803764
#     - label=1: 20개
#         · 평균 var_score: 0.0032194152372093353
#         · 평균 mean_score: 0.9536244976135396
#     - 전체 평균 var_score: 0.026766704766183265
#     - 전체 평균 mean_score: 0.9024239513886034
#   ▶ length_of_summary = 13 (총 25개)
#     - label=0: 15개
#         · 평균 var_score: 0.08854052815332794
#         · 평균 mean_score: 0.7956249962348897
#     - label=1: 10개
#         · 평균 var_score: 0.023051589844202545
#         · 평균 mean_score: 0.926746915142016
#     - 전체 평균 var_score: 0.06234495282967777
#     - 전체 평균 mean_score: 0.8480737637977401
#   ▶ length_of_summary = 14 (총 6개)
#     - label=0: 3개
#         · 평균 var_score: 0.046965220468076996
#         · 평균 mean_score: 0.8770273488092547
#     - label=1: 3개
#         · 평균 var_score: 0.017601404818815527
#         · 평균 mean_score: 0.9205874934171637
#     - 전체 평균 var_score: 0.03228331264344626
#     - 전체 평균 mean_score: 0.898807421113209
#   ▶ length_of_summary = 15 (총 7개)
#     - label=0: 1개
#         · 평균 var_score: 0.00473266704517641
#         · 평균 mean_score: 0.9528249766522398
#     - label=1: 6개
#         · 평균 var_score: 0.010979431732487187
#         · 평균 mean_score: 0.9386821304441483
#     - 전체 평균 var_score: 0.010087036777157077
#     - 전체 평균 mean_score: 0.9407025370453042
#   ▶ length_of_summary = 16 (총 2개)
#     - label=0: 1개
#         · 평균 var_score: 0.0012962854342616406
#         · 평균 mean_score: 0.971486363785516
#     - label=1: 1개
#         · 평균 var_score: 9.539099075256002e-05
#         · 평균 mean_score: 0.9802795402792981
#     - 전체 평균 var_score: 0.0006958382125071003
#     - 전체 평균 mean_score: 0.975882952032407
#   ▶ length_of_summary = 17 (총 1개)
#     - label=0: 0개
#         · 평균 var_score: None
#         · 평균 mean_score: None
#     - label=1: 1개
#         · 평균 var_score: 0.0021568699970849823
#         · 평균 mean_score: 0.9444978736745029
#     - 전체 평균 var_score: 0.0021568699970849823
#     - 전체 평균 mean_score: 0.9444978736745029
#   ▶ length_of_summary = 18 (총 2개)
#     - label=0: 1개
#         · 평균 var_score: 0.046253431736173446
#         · 평균 mean_score: 0.9238963718784766
#     - label=1: 1개
#         · 평균 var_score: 0.0019590042933147417
#         · 평균 mean_score: 0.9502913626686981
#     - 전체 평균 var_score: 0.024106218014744094
#     - 전체 평균 mean_score: 0.9370938672735873
#   ▶ length_of_summary = 22 (총 1개)
#     - label=0: 1개
#         · 평균 var_score: 0.023407989184635193
#         · 평균 mean_score: 0.938509479154494
#     - label=1: 0개
#         · 평균 var_score: None
#         · 평균 mean_score: None
#     - 전체 평균 var_score: 0.023407989184635193
#     - 전체 평균 mean_score: 0.938509479154494
#
# 📄 fizz_original_xsumfaith_e_min.json
#   ▶ length_of_summary = 1 (총 30개)
#     - label=0: 28개
#         · 평균 var_score: 0.0
#         · 평균 mean_score: 0.19551978167146444
#     - label=1: 2개
#         · 평균 var_score: 0.0
#         · 평균 mean_score: 0.761125773191452
#     - 전체 평균 var_score: 0.0
#     - 전체 평균 mean_score: 0.23322684777279695
#   ▶ length_of_summary = 2 (총 282개)
#     - label=0: 246개
#         · 평균 var_score: 0.045498874324362476
#         · 평균 mean_score: 0.31900821861525147
#     - label=1: 36개
#         · 평균 var_score: 0.03455863831138301
#         · 평균 mean_score: 0.5863465136305118
#     - 전체 평균 var_score: 0.04410224845036509
#     - 전체 평균 mean_score: 0.353136511595923
#   ▶ length_of_summary = 3 (총 514개)
#     - label=0: 455개
#         · 평균 var_score: 0.06218612958997022
#         · 평균 mean_score: 0.3193854535229234
#     - label=1: 59개
#         · 평균 var_score: 0.05645210615683646
#         · 평균 mean_score: 0.5913089241616764
#     - 전체 평균 var_score: 0.061527944020797275
#     - 전체 평균 mean_score: 0.35059845890752744
#   ▶ length_of_summary = 4 (총 302개)
#     - label=0: 280개
#         · 평균 var_score: 0.07493460896955824
#         · 평균 mean_score: 0.3398051002946886
#     - label=1: 22개
#         · 평균 var_score: 0.06177146820795453
#         · 평균 mean_score: 0.6188462376012467
#     - 전체 평균 var_score: 0.07397570467566658
#     - 전체 평균 mean_score: 0.36013260036337824
#   ▶ length_of_summary = 5 (총 103개)
#     - label=0: 95개
#         · 평균 var_score: 0.07818224493459816
#         · 평균 mean_score: 0.30611919445671926
#     - label=1: 8개
#         · 평균 var_score: 0.08265794688953833
#         · 평균 mean_score: 0.5422486780793406
#     - 전체 평균 var_score: 0.07852987227090419
#     - 전체 평균 mean_score: 0.3244593485244957
#   ▶ length_of_summary = 6 (총 16개)
#     - label=0: 16개
#         · 평균 var_score: 0.08864613106163105
#         · 평균 mean_score: 0.33710131264645804
#     - label=1: 0개
#         · 평균 var_score: None
#         · 평균 mean_score: None
#     - 전체 평균 var_score: 0.08864613106163105
#     - 전체 평균 mean_score: 0.33710131264645804
#   ▶ length_of_summary = 7 (총 2개)
#     - label=0: 2개
#         · 평균 var_score: 0.11493289061813185
#         · 평균 mean_score: 0.2628583882802299
#     - label=1: 0개
#         · 평균 var_score: None
#         · 평균 mean_score: None
#     - 전체 평균 var_score: 0.11493289061813185
#     - 전체 평균 mean_score: 0.2628583882802299
#   ▶ length_of_summary = 8 (총 1개)
#     - label=0: 1개
#         · 평균 var_score: 0.0706939225671425
#         · 평균 mean_score: 0.19657355296658352
#     - label=1: 0개
#         · 평균 var_score: None
#         · 평균 mean_score: None
#     - 전체 평균 var_score: 0.0706939225671425
#     - 전체 평균 mean_score: 0.19657355296658352
