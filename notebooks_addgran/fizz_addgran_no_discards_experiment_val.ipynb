# %%
datasetname = "cogensumm"

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import json
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the JSON file
file_path = f"../results_addgran/fizz_rouge_{datasetname}_no_discards.json"

with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# ✅ "cut"이 "val"인 항목만 필터링
val_data = [entry for entry in data if entry.get("cut") == "val"]

# ✅ 점수 및 라벨 추출
scores = np.array([entry["score"] for entry in val_data])
labels = np.array([entry["label"] for entry in val_data])

# ✅ ROC-AUC 계산
roc_auc = roc_auc_score(labels, scores)

# ✅ ROC 곡선 좌표 계산
fpr, tpr, _ = roc_curve(labels, scores)

# ✅ ROC 곡선 그리기
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, marker='.', label=f'ROC-AUC = {roc_auc:.4f}')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (cut=val)')
plt.legend()
plt.grid()
plt.show()

# ✅ 최종 결과 출력
print(f"ROC-AUC Score (cut=val): {roc_auc:.4f}")
# Out:
# ROC-AUC Score (cut=val): 0.7106

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import json
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the JSON file
file_path = f"../results_addgran/fizz_rouge_sbert_{datasetname}_no_discards.json"

with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# ✅ "cut"이 "val"인 항목만 필터링
val_data = [entry for entry in data if entry.get("cut") == "val"]

# ✅ 점수 및 라벨 추출
scores = np.array([entry["score"] for entry in val_data])
labels = np.array([entry["label"] for entry in val_data])

# ✅ ROC-AUC 계산
roc_auc = roc_auc_score(labels, scores)

# ✅ ROC 곡선 좌표 계산
fpr, tpr, _ = roc_curve(labels, scores)

# ✅ ROC 곡선 그리기
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, marker='.', label=f'ROC-AUC = {roc_auc:.4f}')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (cut=val)')
plt.legend()
plt.grid()
plt.show()

# ✅ 최종 결과 출력
print(f"ROC-AUC Score (cut=val): {roc_auc:.4f}")
# Out:
# ROC-AUC Score (cut=val): 0.7141

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import json
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the JSON file
file_path = f"../results_addgran/fizz_sbert_{datasetname}_no_discards.json"

with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# ✅ "cut"이 "val"인 항목만 필터링
val_data = [entry for entry in data if entry.get("cut") == "val"]

# ✅ 점수 및 라벨 추출
scores = np.array([entry["score"] for entry in val_data])
labels = np.array([entry["label"] for entry in val_data])

# ✅ ROC-AUC 계산
roc_auc = roc_auc_score(labels, scores)

# ✅ ROC 곡선 좌표 계산
fpr, tpr, _ = roc_curve(labels, scores)

# ✅ ROC 곡선 그리기
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, marker='.', label=f'ROC-AUC = {roc_auc:.4f}')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (cut=val)')
plt.legend()
plt.grid()
plt.show()

# ✅ 최종 결과 출력
print(f"ROC-AUC Score (cut=val): {roc_auc:.4f}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 9
#       6 # Load the data from the JSON file
#       7 file_path = f"../results_addgran/fizz_sbert_{datasetname}_no_discards.json"
# ----> 9 with open(file_path, "r", encoding="utf-8") as f:
#      10     data = json.load(f)
#      12 # ✅ "cut"이 "val"인 항목만 필터링
#
# File /workspace/venvs/FIZZvenv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results_addgran/fizz_sbert_cogensumm_no_discards.json'

# %%
from sklearn.metrics import precision_recall_curve, auc
import json
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the JSON file
file_path = f"../results_addgran/fizz_rouge_{datasetname}_no_discards.json"

with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# ✅ "cut"이 "val"인 항목만 필터링
val_data = [entry for entry in data if entry.get("cut") == "val"]

# ✅ 점수 및 라벨 추출
scores = np.array([entry["score"] for entry in val_data])
labels = np.array([entry["label"] for entry in val_data])

# ✅ PR-AUC 계산 (모델)
precision, recall, _ = precision_recall_curve(labels, scores)
pr_auc = auc(recall, precision)

# ✅ 랜덤 분류기의 PR-AUC 계산 (baseline 비교용)
random_scores = np.random.rand(len(labels))
random_precision, random_recall, _ = precision_recall_curve(labels, random_scores)
random_pr_auc = auc(random_recall, random_precision)

# ✅ PR Curve Plot
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.', label=f'PR-AUC (Model) = {pr_auc:.4f}')
plt.plot(random_recall, random_precision, linestyle='--', color='red', label=f'PR-AUC (Random) = {random_pr_auc:.4f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (cut=val)')
plt.legend()
plt.grid()
plt.show()

# ✅ 결과 출력
print(f"PR-AUC (Model, cut=val): {pr_auc:.4f}")
print(f"PR-AUC (Random baseline): {random_pr_auc:.4f}")
# Out:
# PR-AUC (Model, cut=val): 0.6911
# PR-AUC (Random baseline): 0.4841

# %%
from sklearn.metrics import precision_recall_curve, auc
import json
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the JSON file
file_path = f"../results_addgran/fizz_rouge_sbert_{datasetname}_no_discards.json"

with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# ✅ "cut"이 "val"인 항목만 필터링
val_data = [entry for entry in data if entry.get("cut") == "val"]

# ✅ 점수 및 라벨 추출
scores = np.array([entry["score"] for entry in val_data])
labels = np.array([entry["label"] for entry in val_data])

# ✅ PR-AUC 계산 (모델)
precision, recall, _ = precision_recall_curve(labels, scores)
pr_auc = auc(recall, precision)

# ✅ 랜덤 분류기의 PR-AUC 계산 (baseline 비교용)
random_scores = np.random.rand(len(labels))
random_precision, random_recall, _ = precision_recall_curve(labels, random_scores)
random_pr_auc = auc(random_recall, random_precision)

# ✅ PR Curve Plot
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.', label=f'PR-AUC (Model) = {pr_auc:.4f}')
plt.plot(random_recall, random_precision, linestyle='--', color='red', label=f'PR-AUC (Random) = {random_pr_auc:.4f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (cut=val)')
plt.legend()
plt.grid()
plt.show()

# ✅ 결과 출력
print(f"PR-AUC (Model, cut=val): {pr_auc:.4f}")
print(f"PR-AUC (Random baseline): {random_pr_auc:.4f}")
# Out:
# PR-AUC (Model, cut=val): 0.6942
# PR-AUC (Random baseline): 0.5284

# %%
from sklearn.metrics import precision_recall_curve, auc
import json
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the JSON file
file_path = f"../results_addgran/fizz_sbert_{datasetname}_no_discards.json"

with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# ✅ "cut"이 "val"인 항목만 필터링
val_data = [entry for entry in data if entry.get("cut") == "val"]

# ✅ 점수 및 라벨 추출
scores = np.array([entry["score"] for entry in val_data])
labels = np.array([entry["label"] for entry in val_data])

# ✅ PR-AUC 계산 (모델)
precision, recall, _ = precision_recall_curve(labels, scores)
pr_auc = auc(recall, precision)

# ✅ 랜덤 분류기의 PR-AUC 계산 (baseline 비교용)
random_scores = np.random.rand(len(labels))
random_precision, random_recall, _ = precision_recall_curve(labels, random_scores)
random_pr_auc = auc(random_recall, random_precision)

# ✅ PR Curve Plot
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.', label=f'PR-AUC (Model) = {pr_auc:.4f}')
plt.plot(random_recall, random_precision, linestyle='--', color='red', label=f'PR-AUC (Random) = {random_pr_auc:.4f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (cut=val)')
plt.legend()
plt.grid()
plt.show()

# ✅ 결과 출력
print(f"PR-AUC (Model, cut=val): {pr_auc:.4f}")
print(f"PR-AUC (Random baseline): {random_pr_auc:.4f}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 9
#       6 # Load the data from the JSON file
#       7 file_path = f"../results_addgran/fizz_sbert_{datasetname}_no_discards.json"
# ----> 9 with open(file_path, "r", encoding="utf-8") as f:
#      10     data = json.load(f)
#      12 # ✅ "cut"이 "val"인 항목만 필터링
#
# File /workspace/venvs/FIZZvenv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results_addgran/fizz_sbert_cogensumm_no_discards.json'
